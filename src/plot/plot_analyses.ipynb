# %%
import numpy as np
import os 
import cv2
import random
import sys 
import csv
import pandas as pd
import bz2
from bz2 import BZ2File
from datetime import datetime
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import seaborn as sns
from glob import glob
import fnmatch

from sklearn.metrics import *
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import KFold
from sklearn.decomposition import PCA
from sklearn.metrics import roc_auc_score
from sklearn.preprocessing import LabelBinarizer
import shutil

# %%
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

sns.set_theme()
sns.set_style("darkgrid")
colors = sns.color_palette("Paired", n_colors=10)
colors.reverse()

fig = plt.figure(figsize=(5, 3)) 
ax = plt.subplot(1, 1, 1)
X = ['Asian','Black','White','Overall','Equity-Scaled']

output_file = '/data/home/luoy/project/python/fairness_learning/fairness_learning/data4paper/gf_perf_models_race.pdf'

# race
# 0.7788, 0.7566, 0.7786, 0.7717, 0.7499

vit = [0.778,0.767,0.767, 0.77, 0.76]
resnet = [0.8603,0.8023,0.8205, 0.8211, 0.7756]
effnet = [0.8832,0.8218,0.8268, 0.8311,0.78]

X_axis = np.arange(len(X))
  
plt.bar(X_axis - 0.3, vit, 0.3, color=colors[0], label = 'Vision Transformer')
plt.bar(X_axis, resnet, 0.3, color=colors[1], label = 'ResNet')
plt.bar(X_axis + 0.3, effnet, 0.3, color=colors[2], label = 'EfficientNet')

ax.set_ylim(0.6,1.05) 
plt.xticks(X_axis, X, rotation=10, fontsize =10)
plt.ylabel("AUC", fontsize =10)
ax.legend(loc='best', fontsize=10)
# plt.show()

for p in ax.patches:
    ax.annotate('{:.2f}'.format((p.get_height())), (p.get_x()-0.03, p.get_height() + .012), size=7)

# plt.grid(linestyle='dotted')
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

plt.savefig(output_file, format='pdf', bbox_inches='tight')

# %%
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

sns.set_theme()
sns.set_style("darkgrid")
colors = sns.color_palette("Paired", n_colors=10)
colors.reverse()

output_file = '/data/home/luoy/project/python/fairness_learning/fairness_learning/data4paper/gf_perf_models_gender.pdf'


fig = plt.figure(figsize=(4, 3)) 
ax = plt.subplot(1, 1, 1)
X = ['Female','Male','Overall','Equity-Scaled']

# gender
# vit = [0.6712,0.701,0.6822,0.6625]
vit = [0.747,0.797,0.77,0.734]
resnet = [0.7936,0.8607,0.8207,0.7691]
effnet = [0.8112,0.8608,0.8304,0.7911]

X_axis = np.arange(len(X))
  
plt.bar(X_axis - 0.28, vit, 0.28, color=colors[0], label = 'Vision Transformer')
plt.bar(X_axis, resnet, 0.28, color=colors[1], label = 'ResNet')
plt.bar(X_axis + 0.28, effnet, 0.28, color=colors[2], label = 'EfficientNet')

ax.set_ylim(0.6,1.06) 
plt.xticks(X_axis, X, rotation=10, fontsize =10)
plt.ylabel("AUC", fontsize =10)
ax.legend(loc='best', fontsize=10)
# plt.show()

for p in ax.patches:
    ax.annotate('{:.2f}'.format((p.get_height())), (p.get_x()-0.03, p.get_height() + .012), size=7)

plt.savefig(output_file, format='pdf', bbox_inches='tight')
# plt.savefig('results/yan_benchmark_gender.pdf',
# #             dpi=300,
#             orientation='portrait',
#             bbox_inches='tight', pad_inches=0)

# %%
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

sns.set_theme()
sns.set_style("darkgrid")
colors = sns.color_palette("Paired", n_colors=10)
colors.reverse()

output_file = '/data/home/luoy/project/python/fairness_learning/fairness_learning/data4paper/gf_perf_models_eth.pdf'


fig = plt.figure(figsize=(4, 3)) 
ax = plt.subplot(1, 1, 1)
X = ['Non-Hispanic','Hispanic','Overall','Equity-Scaled']

# hispanic
# vit = [0.7761,0.6689, 0.7707, 0.696]
vit = [0.777,0.681, 0.77, 0.708]
resnet = [0.8277,0.7346, 0.8228, 0.7527]
effnet = [0.834,0.7785, 0.8308, 0.7871]

X_axis = np.arange(len(X))
  
plt.bar(X_axis - 0.28, vit, 0.28, color=colors[0], label = 'Vision Transformer')
plt.bar(X_axis, resnet, 0.28, color=colors[1], label = 'ResNet')
plt.bar(X_axis + 0.28, effnet, 0.28, color=colors[2], label = 'EfficientNet')



ax.set_ylim(0.6,1) 
plt.xticks(X_axis, X, rotation=10, fontsize =10)
plt.ylabel("AUC", fontsize =10)
ax.legend(loc='best', fontsize=10)
# plt.show()

for p in ax.patches:
    ax.annotate('{:.2f}'.format((p.get_height())), (p.get_x()-0.03, p.get_height() + .012), size=7)

plt.savefig(output_file, format='pdf', bbox_inches='tight')
# plt.savefig('results/yan_benchmark_hispanic.pdf',
# #             dpi=300,
#             orientation='portrait',
#             bbox_inches='tight', pad_inches=0)

# %%
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

sns.set_theme()
sns.set_style("darkgrid")
colors = sns.color_palette("Paired", n_colors=10)
colors.reverse()

output_file = '/data/home/luoy/project/python/fairness_learning/fairness_learning/data4paper/gf_perf_fin_race.pdf'


fig = plt.figure(figsize=(4, 3)) 
ax = plt.subplot(1, 1, 1)
X = ['Asian','Black','White','Overall','Equity-Scaled']
y1 = [0.8800,0.7946,0.8628,0.8497,0.7736]
y2 = [0.8802,0.8215,0.8626,0.8612,0.8100]
  
X_axis = np.arange(len(X))
  
plt.bar(X_axis - 0.18, y1, 0.36, label = 'EfficientNet', color=colors[7])
plt.bar(X_axis + 0.18, y2, 0.36, label = 'EfficientNet w/ FIN', color=colors[2])
ax.set_ylim(0.6,1) 
plt.xticks(X_axis, X, rotation=10, fontsize =10)
plt.ylabel("AUC", fontsize =10)
ax.legend(loc='best', fontsize=10)
# plt.show()

for p in ax.patches:
    ax.annotate('{:.2f}'.format((p.get_height())), (p.get_x()-0.03, p.get_height() + .012), size=7)

plt.savefig(output_file, format='pdf', bbox_inches='tight')
# plt.savefig('results/yan_EyeFair_race.pdf',
# #             dpi=300,
#             orientation='portrait',
#             bbox_inches='tight', pad_inches=0)

# %%
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

sns.set_theme()
sns.set_style("darkgrid")
colors = sns.color_palette("Paired", n_colors=10)
colors.reverse()

output_file = '/data/home/luoy/project/python/fairness_learning/fairness_learning/data4paper/gf_perf_fin_gender.pdf'


fig = plt.figure(figsize=(4, 3)) 
ax = plt.subplot(1, 1, 1)
X = ['Female','Male','Overall','Equity-Scaled']

# gender
y1 = [0.8540,0.8487,0.8505,0.8383]
y2 = [0.8598,0.8617,0.8604,0.8561]
  
X_axis = np.arange(len(X))
  
plt.bar(X_axis - 0.15, y1, 0.3, label = 'EfficientNet', color=colors[7])
plt.bar(X_axis + 0.15, y2, 0.3, label = 'EfficientNet w/ FIN', color=colors[2])
ax.set_ylim(0.6,1.04) 
plt.xticks(X_axis, X, rotation=10, fontsize =10)
plt.ylabel("AUC", fontsize =10)
ax.legend(loc='best', fontsize=10)
# plt.show()

for p in ax.patches:
    ax.annotate('{:.2f}'.format((p.get_height())), (p.get_x()+0.03, p.get_height() + .012), size=7)

plt.savefig(output_file, format='pdf', bbox_inches='tight')

# %%
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

sns.set_theme()
sns.set_style("darkgrid")
colors = sns.color_palette("Paired", n_colors=10)
colors.reverse()

output_file = '/data/home/luoy/project/python/fairness_learning/fairness_learning/data4paper/gf_perf_fin_eth.pdf'


fig = plt.figure(figsize=(4, 3)) 
ax = plt.subplot(1, 1, 1)
X = ['Non-Hispanic','Hispanic','Overall','Equity-Scaled']

# ethnicity
y1 = [0.8456, 0.9167,0.8505,0.7912]
y2 = [0.8568, 0.9306, 0.8604, 0.8012]
  
X_axis = np.arange(len(X))
  
plt.bar(X_axis - 0.15, y1, 0.3, label = 'EfficientNet', color=colors[7])
plt.bar(X_axis + 0.15, y2, 0.3, label = 'EfficientNet w/ FIN', color=colors[2])
ax.set_ylim(0.7,1.04) 
plt.xticks(X_axis, X, rotation=10, fontsize =10)
plt.ylabel("AUC", fontsize =10)
ax.legend(loc='best', fontsize=10)
# plt.show()

for p in ax.patches:
    ax.annotate('{:.2f}'.format((p.get_height())), (p.get_x()+0.03, p.get_height() + .012), size=7)

plt.savefig(output_file, format='pdf', bbox_inches='tight')

# %%
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

sns.set_theme()
sns.set_style("darkgrid")
colors = sns.color_palette("Paired", n_colors=10)
colors.reverse()

output_file = '/data/home/luoy/project/python/fairness_learning/fairness_learning/data4paper/gf_perf_oct_fin_race.pdf'

# 0.7194, 0.7758, 0.8012, 0.7345, 0.7875
# 0.7531, 0.7957, 0.8142, 0.7671, 0.7863


fig = plt.figure(figsize=(4, 3)) 
ax = plt.subplot(1, 1, 1)
X = ['Asian','Black','White','Overall','Equity-Scaled']
y1 = [0.8012, 0.7345, 0.7875, 0.7758, 0.7194]
y2 = [0.8142, 0.7671, 0.7863, 0.7957, 0.7531]
  
X_axis = np.arange(len(X))
  
plt.bar(X_axis - 0.18, y1, 0.36, label = 'EfficientNet', color=colors[7])
plt.bar(X_axis + 0.18, y2, 0.36, label = 'EfficientNet w/ FIN', color=colors[2])
ax.set_ylim(0.6,.9) 
plt.xticks(X_axis, X, rotation=10, fontsize =10)
plt.ylabel("AUC", fontsize =10)
ax.legend(loc='best', fontsize=10)
# plt.show()

for p in ax.patches:
    ax.annotate('{:.2f}'.format((p.get_height())), (p.get_x()-0.03, p.get_height() + .012), size=7)

plt.savefig(output_file, format='pdf', bbox_inches='tight')

# %%
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

sns.set_theme()
sns.set_style("darkgrid")
colors = sns.color_palette("Paired", n_colors=10)
colors.reverse()

output_file = '/data/home/luoy/project/python/fairness_learning/fairness_learning/data4paper/gf_perf_oct_fin_gender.pdf'


fig = plt.figure(figsize=(4, 3)) 
ax = plt.subplot(1, 1, 1)
X = ['Female','Male','Overall','Equity-Scaled']

# gender
# 0.7668, 0.8092, 0.7867, 0.7547
# 0.7893, 0.8023, 0.7949, 0.7847
y1 = [0.7668, 0.8092, 0.7867, 0.7547]
y2 = [0.7893, 0.8023, 0.7949, 0.7847]
  
X_axis = np.arange(len(X))
  
plt.bar(X_axis - 0.15, y1, 0.3, label = 'EfficientNet', color=colors[7])
plt.bar(X_axis + 0.15, y2, 0.3, label = 'EfficientNet w/ FIN', color=colors[2])
ax.set_ylim(0.6,.9) 
plt.xticks(X_axis, X, rotation=10, fontsize =10)
plt.ylabel("AUC", fontsize =10)
ax.legend(loc='best', fontsize=10)
# plt.show()

for p in ax.patches:
    ax.annotate('{:.2f}'.format((p.get_height())), (p.get_x()+0.03, p.get_height() + .012), size=7)

plt.savefig(output_file, format='pdf', bbox_inches='tight')

# %%
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

sns.set_theme()
sns.set_style("darkgrid")
colors = sns.color_palette("Paired", n_colors=10)
colors.reverse()

output_file = '/data/home/luoy/project/python/fairness_learning/fairness_learning/data4paper/gf_perf_oct_fin_eth.pdf'


fig = plt.figure(figsize=(4, 3)) 
ax = plt.subplot(1, 1, 1)
X = ['Non-Hispanic','Hispanic','Overall','Equity-Scaled']

# ethnicity
y1 = [0.8456, 0.9167,0.8505,0.7912]
y2 = [0.8568, 0.9306, 0.8604, 0.8012]
  
X_axis = np.arange(len(X))
  
plt.bar(X_axis - 0.15, y1, 0.3, label = 'EfficientNet', color=colors[7])
plt.bar(X_axis + 0.15, y2, 0.3, label = 'EfficientNet w/ FIN', color=colors[2])
ax.set_ylim(0.7,1.04) 
plt.xticks(X_axis, X, rotation=10, fontsize =10)
plt.ylabel("AUC", fontsize =10)
ax.legend(loc='best', fontsize=10)
# plt.show()

for p in ax.patches:
    ax.annotate('{:.2f}'.format((p.get_height())), (p.get_x()+0.03, p.get_height() + .012), size=7)

plt.savefig(output_file, format='pdf', bbox_inches='tight')

# %%
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

sns.set_theme()
sns.set_style("darkgrid")
colors = sns.color_palette("Paired", n_colors=10)
colors.reverse()

output_file = '/data/home/luoy/project/python/fairness_learning/fairness_learning/data4paper/gf_perf_fin_race_dl.pdf'


fig = plt.figure(figsize=(4, 3)) 
ax = plt.subplot(1, 1, 1)
X = ['Asian','Black','White','Overall']
y1 = [0.8800,0.7946,0.8628,0.8497]
y2 = [0.8802,0.8215,0.8626,0.8612]
  
X_axis = np.arange(len(X))
  
plt.bar(X_axis - 0.18, y1, 0.36, label = 'EfficientNet', color=colors[7])
# plt.bar(X_axis + 0.18, y2, 0.36, label = 'EfficientNet w/ FIN', color=colors[2])
ax.set_ylim(0.7,0.95) 
plt.xticks(X_axis, X, rotation=10, fontsize =10)
plt.ylabel("AUC", fontsize =10)
# ax.legend(loc='best', fontsize=10)
# plt.show()

for p in ax.patches:
    ax.annotate('{:.2f}'.format((p.get_height())), (p.get_x()-0.03, p.get_height() + .012), size=7)

plt.savefig(output_file, format='pdf', bbox_inches='tight')
# plt.savefig('results/yan_EyeFair_race.pdf',
# #             dpi=300,
#             orientation='portrait',
#             bbox_inches='tight', pad_inches=0)

# %%
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

sns.set_theme()
sns.set_style("darkgrid")
colors = sns.color_palette("Paired", n_colors=10)
colors.reverse()

output_file = '/data/home/luoy/project/python/fairness_learning/fairness_learning/data4paper/gf_perf_fin_race_equitabledl.pdf'


fig = plt.figure(figsize=(4, 3)) 
ax = plt.subplot(1, 1, 1)
X = ['Asian','Black','White','Overall']
y1 = [0.8800,0.7946,0.8628,0.8497]
y2 = [0.8802,0.8215,0.8626,0.8612]
  
X_axis = np.arange(len(X))
  
# plt.bar(X_axis - 0.18, y1, 0.36, label = 'EfficientNet', color=colors[7])
plt.bar(X_axis + 0.18, y2, 0.36, label = 'EfficientNet w/ FIN', color=colors[2])
ax.set_ylim(0.7, 0.95) 
plt.xticks(X_axis, X, rotation=10, fontsize =10)
plt.ylabel("AUC", fontsize =10)
# ax.legend(loc='best', fontsize=10)
# plt.show()

for p in ax.patches:
    ax.annotate('{:.2f}'.format((p.get_height())), (p.get_x()-0.03, p.get_height() + .012), size=7)

plt.savefig(output_file, format='pdf', bbox_inches='tight')
# plt.savefig('results/yan_EyeFair_race.pdf',
# #             dpi=300,
#             orientation='portrait',
#             bbox_inches='tight', pad_inches=0)
